# %% [markdown]
# ## Index Data

# %% [markdown]
# import packages

# %%
from elasticsearch import Elasticsearch
from elasticsearch.helpers import bulk
import pandas as pd
from credentials import username, password

# %% [markdown]
# Connect to elasticsearch

# %%
es = Elasticsearch(
    "http://localhost:9200",
    basic_auth=(username, password)
)

# %% [markdown]
# ### Create index with analysers

# %%
mappings = {
    "properties": {
        "cord_uid": {"type": "keyword"},
        "sha": {"type": "keyword"},
        "source_x": {"type": "keyword"},
        "title":{"type": "text"},
        "doi": {"type": "keyword"},
        "pmcid": {"type": "keyword"},
        "pubmed_id": {"type": "integer"},
        "license": {"type": "keyword"},
        "abstract": {"type": "text", "normalizer": "my-normalizer"},
        "publish_time": {"type": "date"},
        "authors": {"type": "text"},
        "journal": {"type": "text"},
        "mag_id": {"type": "keyword"},
        "who_covidence_id": {"type": "keyword"},
        "arxiv_id": {"type": "keyword"},
        "pdf_json_files": {"type": "keyword"},
        "pmc_json_files": {"type": "keyword"},
        "url": {"type": "keyword"},
        "s2_id": {"type": "keyword"}
    }
}

# %%
settings = {
    "analysis": {
        "analyzer": {
            "my-analyzer": {
                "type": "custom",
                "tokenizer": "standard",
                "filter": ["stop"]
          } 
        },
        "normalizer": {
            "my-normalizer": {
                "type": "custom",
                "char_filter": [],
                "filter": ["lowercase", "asciifolding"]
            }
        }
    }
}

# %%
index = "test2"
# es.indices.delete(index=index)
es.indices.create(index=index, mappings=mappings, settings=settings)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In [12], line 3
#       1 index = "test2"
#       2 # es.indices.delete(index=index)
# ----> 3 es.indices.create(index=index, mappings=mappings, settings=settings)
#
# File ~/pg/DIS17.1/.elastic_env/lib/python3.10/site-packages/elasticsearch/_sync/client/utils.py:414, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     411         except KeyError:
#     412             pass
# --> 414 return api(*args, **kwargs)
#
# File ~/pg/DIS17.1/.elastic_env/lib/python3.10/site-packages/elasticsearch/_sync/client/indices.py:517, in IndicesClient.create(self, index, aliases, error_trace, filter_path, human, mappings, master_timeout, pretty, settings, timeout, wait_for_active_shards)
#     515 if __body is not None:
#     516     __headers["content-type"] = "application/json"
# --> 517 return self.perform_request(  # type: ignore[return-value]
#     518     "PUT", __path, params=__query, headers=__headers, body=__body
#     519 )
#
# File ~/pg/DIS17.1/.elastic_env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:390, in NamespacedClient.perform_request(self, method, path, params, headers, body)
#     379 def perform_request(
#     380     self,
#     381     method: str,
#    (...)
#     388     # Use the internal clients .perform_request() implementation
#     389     # so we take advantage of their transport options.
# --> 390     return self._client.perform_request(
#     391         method, path, params=params, headers=headers, body=body
#     392     )
#
# File ~/pg/DIS17.1/.elastic_env/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:321, in BaseClient.perform_request(self, method, path, params, headers, body)
#     318         except (ValueError, KeyError, TypeError):
#     319             pass
# --> 321     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     322         message=message, meta=meta, body=resp_body
#     323     )
#     325 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     326 if not self._verified_elasticsearch:
#     327     # If the header is set we mark the server as verified.
#
# BadRequestError: BadRequestError(400, 'mapper_parsing_exception', 'unknown parameter [normalizer] on mapper [abstract] of type [text]')

# %% [markdown]
# ### Index the data

# %% [markdown]
# load data from [Moodle](https://elearning.iws.th-koeln.de/moodle/mod/resource/view.php?id=62943) and place into data

# %%
md = pd.read_csv("data/metadata.csv")
md.head(5)
# Out:
# /tmp/ipykernel_200771/851210104.py:1: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   md = pd.read_csv("data/metadata.csv")
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# 3               Role of endothelin-1 in lung disease           10.1186/rr44
# 4  Gene expression in epithelial cells in respons...           10.1186/rr61
#
#       pmcid   pubmed_id license  \
# 0  PMC35282  11472636.0   no-cc
# 1  PMC59543  11667967.0   no-cc
# 2  PMC59549  11667972.0   no-cc
# 3  PMC59574  11686871.0   no-cc
# 4  PMC59580  11686888.0   no-cc
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
#
#                                              authors         journal  mag_id  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A  BMC Infect Dis     NaN
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...      Respir Res     NaN
# 2                                    Crouch, Erika C      Respir Res     NaN
# 3  Fagan, Karen A; McMurtry, Ivan F; Rodman, David M      Respir Res     NaN
# 4  Domachowske, Joseph B; Bonville, Cynthia A; Ro...      Respir Res     NaN
#
#   who_covidence_id arxiv_id  \
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
#
#                                       pdf_json_files  \
# 0  document_parses/pdf_json/d1aafb70c066a2068b027...
# 1  document_parses/pdf_json/6b0567729c2143a66d737...
# 2  document_parses/pdf_json/06ced00a5fc04215949aa...
# 3  document_parses/pdf_json/348055649b6b8cf2b9a37...
# 4  document_parses/pdf_json/5f48792a5fa08bed9f560...
#
#                                pmc_json_files  \
# 0  document_parses/pmc_json/PMC35282.xml.json
# 1  document_parses/pmc_json/PMC59543.xml.json
# 2  document_parses/pmc_json/PMC59549.xml.json
# 3  document_parses/pmc_json/PMC59574.xml.json
# 4  document_parses/pmc_json/PMC59580.xml.json
#
#                                                  url  s2_id
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3...    NaN
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...    NaN

# %%
md_sorted = md.iloc[md.isnull().sum(1).sort_values(ascending=1).index]

# %%
md_unique = md_sorted.drop_duplicates(subset=["cord_uid"], keep="first")
md_unique.reset_index(inplace=True, drop=True)

# %%
md_unique
# Out:
#         cord_uid                                                sha  \
# 0       nc8cdgqo  591d913cad0522dcf942f213523920ae786b8a0c; d772...
# 1       5jvuxob7           6c370a406b393ff0c6c1a4c44b8886050a34c2ba
# 2       8mj8gjv9           0a4379cb820735fce01ca648ecdab069f91d284d
# 3       okjm7kjo           4ca24acb1b198b40e74baa74a97067562417e7fc
# 4       m6479wyv  fd05a8fff57b7100589390bcd74f1752cbf5ddcd; 1267...
# ...          ...                                                ...
# 191170  4iunmx2w                                                NaN
# 191171  t6gqa48n                                                NaN
# 191172  w6r7nje8                                                NaN
# 191173  4e3enu6z                                                NaN
# 191174  f16n9i8w                                                NaN
#
#                                   source_x  \
# 0                 ArXiv; Medline; PMC; WHO
# 1       ArXiv; Elsevier; Medline; PMC; WHO
# 2                 ArXiv; Medline; PMC; WHO
# 3       ArXiv; Elsevier; Medline; PMC; WHO
# 4       ArXiv; Elsevier; Medline; PMC; WHO
# ...                                    ...
# 191170                                 WHO
# 191171                                 WHO
# 191172                                 WHO
# 191173                                 WHO
# 191174                                 WHO
#
#                                                     title  \
# 0       Using Early Data to Estimate the Actual Infect...
# 1       Investigating the dynamics of COVID-19 pandemi...
# 2       Modeling the role of respiratory droplets in C...
# 3       How to reduce epidemic peaks keeping under con...
# 4       Analysis and forecast of COVID-19 spreading in...
# ...                                                   ...
# 191170  Prevention of Fogging of Protective Eyewear fo...
# 191171  Hypothesis for potential pathogenesis of SARS-...
# 191172  Mental Well-Being of Nursing Staff During the ...
# 191173  Correction: Clinicopathological characteristic...
# 191174  Integrated Infection Control Strategy to Minim...
#
#                                 doi       pmcid pubmed_id    license  \
# 0            10.3390/biology9050097  PMC7284549  32397286      cc-by
# 1       10.1016/j.chaos.2020.109988  PMC7284270  32536763      no-cc
# 2                 10.1063/5.0015984  PMC7327718  32624650      cc-by
# 3       10.1016/j.chaos.2020.109940  PMC7274126  32518474      no-cc
# 4       10.1016/j.chaos.2020.109761  PMC7156225  32308258  els-covid
# ...                             ...         ...       ...        ...
# 191170                          NaN         NaN       NaN        unk
# 191171                          NaN         NaN       NaN        unk
# 191172                          NaN         NaN       NaN        unk
# 191173                          NaN         NaN       NaN        unk
# 191174                          NaN         NaN       NaN        unk
#
#                                                  abstract publish_time  \
# 0       The number of screening tests carried out in F...   2020-05-08
# 1       In this paper, we investigate the ongoing dyna...   2020-06-10
# 2       In this paper, we develop a first principles m...   2020-06-01
# 3       One of the main challenges of the measures aga...   2020-06-05
# 4       Abstract In this note we analyze the temporal ...   2020-05-31
# ...                                                   ...          ...
# 191170                                                NaN         2020
# 191171  Coronavirus disease 2019 (COVID-19) is an infe...          NaN
# 191172                                                NaN         2020
# 191173                                                NaN         2020
# 191174                                                NaN         2020
#
#                                                   authors  \
# 0       Roques, Lionel; Klein, Etienne K; Papaïx, Juli...
# 1       Pai, Chintamani; Bhaskar, Ankush; Rawoot, Vaibhav
# 2       Chaudhuri, Swetaprovo; Basu, Saptarshi; Kabi, ...
# 3                                         Cadoni, Mariano
# 4                      Fanelli, Duccio; Piazza, Francesco
# ...                                                   ...
# 191170                                                NaN
# 191171                                                NaN
# 191172                                                NaN
# 191173                                                NaN
# 191174                                                NaN
#
#                            journal  mag_id who_covidence_id    arxiv_id  \
# 0                  Biology (Basel)     NaN          #209944   2003.1072
# 1          Chaos Solitons Fractals     NaN          #601738  2004.13337
# 2               Phys Fluids (1994)     NaN          #634223  2004.10929
# 3          Chaos Solitons Fractals     NaN          #594353  2004.02189
# 4       Chaos, Solitons & Fractals     NaN          #100477  2003.06031
# ...                            ...     ...              ...         ...
# 191170                         NaN     NaN          #601490         NaN
# 191171                         NaN     NaN           #11362         NaN
# 191172                         NaN     NaN        #32418672         NaN
# 191173                         NaN     NaN          #598124         NaN
# 191174                         NaN     NaN        #32418674         NaN
#
#                                            pdf_json_files  \
# 0       document_parses/pdf_json/591d913cad0522dcf942f...
# 1       document_parses/pdf_json/6c370a406b393ff0c6c1a...
# 2       document_parses/pdf_json/0a4379cb820735fce01ca...
# 3       document_parses/pdf_json/4ca24acb1b198b40e74ba...
# 4       document_parses/pdf_json/fd05a8fff57b710058939...
# ...                                                   ...
# 191170                                                NaN
# 191171                                                NaN
# 191172                                                NaN
# 191173                                                NaN
# 191174                                                NaN
#
#                                       pmc_json_files  \
# 0       document_parses/pmc_json/PMC7284549.xml.json
# 1       document_parses/pmc_json/PMC7284270.xml.json
# 2       document_parses/pmc_json/PMC7327718.xml.json
# 3       document_parses/pmc_json/PMC7274126.xml.json
# 4       document_parses/pmc_json/PMC7156225.xml.json
# ...                                              ...
# 191170                                           NaN
# 191171                                           NaN
# 191172                                           NaN
# 191173                                           NaN
# 191174                                           NaN
#
#                                                       url        s2_id
# 0       https://arxiv.org/pdf/2003.10720v3.pdf; https:...  218619416.0
# 1       https://www.ncbi.nlm.nih.gov/pubmed/32536763/;...  216562300.0
# 2       https://arxiv.org/pdf/2004.10929v3.pdf; https:...  216562586.0
# 3       https://api.elsevier.com/content/article/pii/S...  214802754.0
# 4       https://api.elsevier.com/content/article/pii/S...  212718235.0
# ...                                                   ...          ...
# 191170                                                NaN  218538953.0
# 191171                                                NaN  214601393.0
# 191172                                                NaN  215801036.0
# 191173                                                NaN  218872883.0
# 191174                                                NaN  215403659.0
#
# [191175 rows x 19 columns]

# %% [markdown]
# ### Use function index_data to send data to elastic

# %%
def index_data(df, index):
    bulk_data = []
    
    for idx, doc in df.iterrows():
        doc_dict = dict(doc)
        if type(doc_dict["pubmed_id"]) != float:
            doc_dict["pubmed_id"] = None
        if type(doc_dict["arxiv_id"]) != float:
            doc_dict["arxiv_id"] = None
        for key in doc_dict.keys():
            if pd.isna(doc_dict[key]):
                doc_dict[key] = None
    
        data = {
            "_index": index,
            "_id": idx,
            "_source": doc_dict
        }
        
        bulk_data.append(data)
    bulk(es, bulk_data)

# %%
start_at_entry = 0
index_data(md_unique.iloc[start_at_entry:], "test")

# %%
es.count(index="test")
# Out:
# ObjectApiResponse({'count': 191175, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}})

# %%
es.indices.analyze(analyzer="standard", text="covid 19")
# Out:
# ObjectApiResponse({'tokens': [{'token': 'covid', 'start_offset': 0, 'end_offset': 5, 'type': '<ALPHANUM>', 'position': 0}, {'token': '19', 'start_offset': 6, 'end_offset': 8, 'type': '<NUM>', 'position': 1}]})
